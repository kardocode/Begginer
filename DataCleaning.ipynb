# %% [markdown]
# <a href="https://colab.research.google.com/github/kardocode/Begginer/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ride_sharing = pd.read_csv('https://raw.githubusercontent.com/pradhrahul/Data-Science-Visualization/refs/heads/main/ride_sharing_clean.csv')

# %%
ride_sharing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25760 entries, 0 to 25759
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   duration         25760 non-null  object
#  1   station_A_id     25760 non-null  int64
#  2   station_A_name   25760 non-null  object
#  3   station_B_id     25760 non-null  int64
#  4   station_B_name   25760 non-null  object
#  5   bike_id          25760 non-null  int64
#  6   user_type        25760 non-null  int64
#  7   user_birth_year  25760 non-null  int64
#  8   user_gender      25760 non-null  object
#  9   tire_sizes       25760 non-null  int64
#  10  ride_dt          25760 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.2+ MB

# %%
ride_sharing.head()
# Out:
#      duration  station_A_id  \
# 0  12 minutes            81
# 1  24 minutes             3
# 2   8 minutes            67
# 3   4 minutes            16
# 4  11 minutes            22
#
#                                       station_A_name  station_B_id  \
# 0                                 Berry St at 4th St           323
# 1       Powell St BART Station (Market St at 4th St)           118
# 2  San Francisco Caltrain Station 2  (Townsend St...            23
# 3                            Steuart St at Market St            28
# 4                              Howard St at Beale St           350
#
#                     station_B_name  bike_id  user_type  user_birth_year  \
# 0               Broadway at Kearny     5480          2             1959
# 1  Eureka Valley Recreation Center     5193          2             1965
# 2    The Embarcadero at Steuart St     3652          3             1993
# 3     The Embarcadero at Bryant St     1883          1             1979
# ...

# %%
ride_sharing['user_type'] = ride_sharing['user_type'].astype(int)
ride_sharing['user_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 25760 entries, 0 to 25759
# Series name: user_type
# Non-Null Count  Dtype
# --------------  -----
# 25760 non-null  int64
# dtypes: int64(1)
# memory usage: 201.4 KB

# %%
ride_sharing['user_type'].describe()
# Out:
# count    25760.000000
# mean         2.008385
# std          0.704541
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          3.000000
# Name: user_type, dtype: float64

# %%
ride_sharing['user_type'].astype('category')
# Out:
# 0        2
# 1        2
# 2        3
# 3        1
# 4        2
#         ..
# 25755    1
# 25756    2
# 25757    2
# 25758    2
# 25759    3
# Name: user_type, Length: 25760, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
ride_sharing['duration'].dtype
# Out:
# dtype('O')

# %%
duration_trim = ride_sharing['duration'].str.strip("minutes")

# %%
ride_sharing['duration'] = duration_trim.astype('int')

# %%
my_dict = {1:"for free ride",2:"for pay ride",3:"for monthly subscribe"}

# %%
ride_sharing["new_user_type"] = ride_sharing['user_type'].map(my_dict)

# %%
ride_sharing['new_user_type'].describe()
# Out:
# count            25760
# unique               3
# top       for pay ride
# freq             12972
# Name: new_user_type, dtype: object

# %%
ride_sharing['duration'].mean()
# Out:
# np.float64(11.389052795031056)

# %%
ride_sharing['tire_sizes'] = ride_sharing['tire_sizes'].astype(int)

# %%
ride_sharing['tire_sizes'].dtype
# Out:
# dtype('int64')

# %%
ride_sharing['tire_sizes'].head()
# Out:
# 0    27
# 1    26
# 2    26
# 3    29
# 4    27
# Name: tire_sizes, dtype: int64

# %%
ride_sharing['tire_sizes'] = ride_sharing.loc[ride_sharing['tire_sizes'] > 27]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1310269558.py in <cell line: 0>()
# ----> 1 ride_sharing['tire_sizes'] = ride_sharing.loc[ride_sharing['tire_sizes'] > 27]
#       2
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4427             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4428             if len_cols != len(value.columns):
# -> 4429                 raise ValueError("Columns must be same length as key")
#    4430
# ...
