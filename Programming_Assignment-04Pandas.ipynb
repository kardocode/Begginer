# %% [markdown]
# <a href="https://colab.research.google.com/github/kardocode/Begginer/blob/main/Programming_Assignment-04Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
stock_price =[150.25, 155.50, 152.00, 158.75, 160.10, 159.90, 161.50];

# %%
stock_prices = pd.Series(stock_price,name="stock_prices")

# %%
import numpy as np

# %%
stock_price =np.array(stock_price);

# %%
print(stock_price)
# Out:
# [150.25 155.5  152.   158.75 160.1  159.9  161.5 ]

# %%
print(stock_prices.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
daily_prices = pd.Series(stock_price,index=week,name="daily_prices")

# %%
week =['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'];

# %%
print(daily_prices.index)
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday'],
#       dtype='object')

# %%
print(daily_prices["Wednesday"])
# Out:
# 152.0

# %%
print(daily_prices[:2])
# Out:
# Monday     150.25
# Tuesday    155.50
# Name: daily_prices, dtype: float64

# %%
print(daily_prices.loc['Monday':'Friday'])
# Out:
# Monday       150.25
# Tuesday      155.50
# Wednesday    152.00
# Thursday     158.75
# Friday       160.10
# Name: daily_prices, dtype: float64

# %%
print(daily_prices[daily_prices>158.00])
# Out:
# Thursday    158.75
# Friday      160.10
# Saturday    159.90
# Sunday      161.50
# Name: daily_prices, dtype: float64

# %%
dict={'P101': 75, 'P102': 120, 'P103': 50, 'P104': 90, 'P105': 15}

# %%
gadget_inventory = pd.Series(dict,name="gadget_inventory")

# %%
product_ID=gadget_inventory.index.tolist();
print(product_ID)

stock_counts = gadget_inventory.values.tolist();
print(stock_counts)
print(gadget_inventory.values.sum())
# Out:
# ['P101', 'P102', 'P103', 'P104', 'P105']
# [75, 120, 50, 90, 15]
# 350

# %%
Low_stock = gadget_inventory[gadget_inventory < 60]
print(Low_stock)
# Out:
# P103    50
# P105    15
# Name: gadget_inventory, dtype: int64

# %%
bill1 = pd.Series(gadget_inventory,name="bill1")
print(bill1)
# Out:
# P101     75
# P102    120
# P103     50
# P104     90
# P105     15
# Name: bill1, dtype: int64

# %%
sales_data = {
    'Product': ['Product A', 'Product B', 'Product C', 'Product D', 'Product E', 'Product F', 'Product G'],
    'Units Sold': [150, 120, 180, 95, 210, 140, 165],
    'Revenue ($)': [75000, 60000, 90000, 47500, 105000, 70000, 82500],
    'Marketing Spend ($)': [1000, 800, 1200, 600, 1500, 950, 1100]
}
print(sales_data)
# Out:
# {'Product': ['Product A', 'Product B', 'Product C', 'Product D', 'Product E', 'Product F', 'Product G'], 'Units Sold': [150, 120, 180, 95, 210, 140, 165], 'Revenue ($)': [75000, 60000, 90000, 47500, 105000, 70000, 82500], 'Marketing Spend ($)': [1000, 800, 1200, 600, 1500, 950, 1100]}
