# %% [markdown]
# <a href="https://colab.research.google.com/github/kardocode/Begginer/blob/main/Assignment-0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Employee:
  def __init__(self,salary,employe_id):
    self.__salary = salary
    self.__employe_id = employe_id
  def get_salary(self):
    return self.__salary
  def set_salary(self,salary):
    self.__salary = salary

my_employee = Employee(100,2415000)
print(my_employee.get_salary())
my_employee.set_salary(20000)
print(my_employee.get_salary())
# Out:
# 100
# 20000

# %% [markdown]
# hello i am making a class in python

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nguyenthianhngoc/favorite-music-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/favorite-music-dataset

# %%
import pandas as pd
music = pd.read_csv(path+'/'+'favorite_music_dataset.csv')

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("adilshamim8/bitcoin-historical-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 108k/108k [00:00<00:00, 39.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/adilshamim8/bitcoin-historical-data/versions/4

# %%
data = pd.read_csv(path+'/'+'Bitcoin_history_data.csv')

# %%
data.head()
# Out:
#          Date       Close        High         Low        Open    Volume
# 0  2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 1  2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2  2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 3  2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 4  2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Low'].plot(kind='hist', bins=20, title='Low')
# ...
